# %%
# !pip install ctgan
# !pip install sdv
# Out:
# Collecting ctgan
#   Downloading ctgan-0.10.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tqdm<5,>=4.29 in /usr/local/lib/python3.10/dist-packages (from ctgan) (4.66.5)
# Collecting rdt>=1.11.0 (from ctgan)
#   Downloading rdt-1.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from ctgan) (2.2.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from ctgan) (2.5.0+cu121)
# Requirement already satisfied: numpy>=1.23.3 in /usr/local/lib/python3.10/dist-packages (from ctgan) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->ctgan) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->ctgan) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->ctgan) (2024.2)
# Collecting Faker>=17 (from rdt>=1.11.0->ctgan)
#   Downloading Faker-30.8.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from rdt>=1.11.0->ctgan) (1.5.2)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from rdt>=1.11.0->ctgan) (1.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->ctgan) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->ctgan) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.0->rdt>=1.11.0->ctgan) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.0->rdt>=1.11.0->ctgan) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->ctgan) (3.0.2)
# Downloading ctgan-0.10.2-py3-none-any.whl (23 kB)
# Downloading rdt-1.13.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 kB 4.0 MB/s eta 0:00:00
# Downloading Faker-30.8.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.1 MB/s eta 0:00:00
# ERROR: Operation cancelled by user
# Collecting sdv
#   Downloading sdv-1.17.1-py3-none-any.whl.metadata (13 kB)
# Collecting boto3<2.0.0,>=1.28 (from sdv)
#   Downloading boto3-1.35.50-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<2.0.0,>=1.31 (from sdv)
#   Downloading botocore-1.35.50-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: cloudpickle>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from sdv) (3.1.0)
# Requirement already satisfied: graphviz>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from sdv) (0.20.3)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.10/dist-packages (from sdv) (4.66.5)
# Collecting copulas>=0.11.0 (from sdv)
#   Downloading copulas-0.11.1-py3-none-any.whl.metadata (9.1 kB)
# Collecting ctgan>=0.10.0 (from sdv)
#   Using cached ctgan-0.10.2-py3-none-any.whl.metadata (10 kB)
# Collecting deepecho>=0.6.0 (from sdv)
#   Downloading deepecho-0.6.1-py3-none-any.whl.metadata (10 kB)
# Collecting rdt>=1.12.3 (from sdv)
#   Using cached rdt-1.13.0-py3-none-any.whl.metadata (10 kB)
# Collecting sdmetrics>=0.16.0 (from sdv)
#   Downloading sdmetrics-0.16.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: platformdirs>=4.0 in /usr/local/lib/python3.10/dist-packages (from sdv) (4.3.6)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from sdv) (6.0.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from sdv) (2.2.2)
# Requirement already satisfied: numpy<2.0.0,>=1.23.3 in /usr/local/lib/python3.10/dist-packages (from sdv) (1.26.4)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<2.0.0,>=1.28->sdv)
#   Downloading s3transfer-0.10.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<2.0.0,>=1.31->sdv) (2.2.3)
# Requirement already satisfied: plotly>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from copulas>=0.11.0->sdv) (5.24.1)
# Requirement already satisfied: scipy>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from copulas>=0.11.0->sdv) (1.13.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from ctgan>=0.10.0->sdv) (2.5.0+cu121)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->sdv) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->sdv) (2024.2)
# Collecting Faker>=17 (from rdt>=1.12.3->sdv)
#   Using cached Faker-30.8.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from rdt>=1.12.3->sdv) (1.5.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from Faker>=17->rdt>=1.12.3->sdv) (4.12.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.10.0->copulas>=0.11.0->sdv) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=5.10.0->copulas>=0.11.0->sdv) (24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.0->rdt>=1.12.3->sdv) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.1.0->rdt>=1.12.3->sdv) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan>=0.10.0->sdv) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan>=0.10.0->sdv) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan>=0.10.0->sdv) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan>=0.10.0->sdv) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan>=0.10.0->sdv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->ctgan>=0.10.0->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->ctgan>=0.10.0->sdv) (3.0.2)
# Downloading sdv-1.17.1-py3-none-any.whl (152 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.3/152.3 kB 7.7 MB/s eta 0:00:00
# Downloading boto3-1.35.50-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 11.3 MB/s eta 0:00:00
# Downloading botocore-1.35.50-py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 87.4 MB/s eta 0:00:00
# Downloading copulas-0.11.1-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.6/51.6 kB 3.9 MB/s eta 0:00:00
# Using cached ctgan-0.10.2-py3-none-any.whl (23 kB)
# Downloading deepecho-0.6.1-py3-none-any.whl (27 kB)
# Using cached rdt-1.13.0-py3-none-any.whl (66 kB)
# Downloading sdmetrics-0.16.0-py3-none-any.whl (170 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 kB 15.3 MB/s eta 0:00:00
# Using cached Faker-30.8.1-py3-none-any.whl (1.8 MB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.10.3-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: jmespath, Faker, botocore, s3transfer, rdt, deepecho, copulas, sdmetrics, ctgan, boto3, sdv
# Successfully installed Faker-30.8.1 boto3-1.35.50 botocore-1.35.50 copulas-0.11.1 ctgan-0.10.2 deepecho-0.6.1 jmespath-1.0.1 rdt-1.13.0 s3transfer-0.10.3 sdmetrics-0.16.0 sdv-1.17.1

# %%
from ctgan import CTGAN

import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
import time

start=time.time()
le = LabelEncoder()

dataset = pd.read_csv('https://raw.githubusercontent.com/mahayasa/various-sampling-churn-prediction/main/data/telco-non-internet.csv')

dataset['state']=le.fit_transform(dataset['state'])
dataset['area_code']=le.fit_transform(dataset['area_code'])
dataset['international_plan']=le.fit_transform(dataset['international_plan'])
dataset['voice_mail_plan']=le.fit_transform(dataset['voice_mail_plan'])
dataset['churn']=le.fit_transform(dataset['churn'])

df1=dataset[dataset['churn']==0]
df=dataset[dataset['churn']==1]

batch_size = 5000
epochs = 100
model = CTGAN(batch_size=batch_size, epochs=epochs, verbose=True)
model.fit(df)

end = time.time()

print("The time of execution of preprocess:",
      (end-start), "s")
# Out:
# Gen. (-1.25) | Discrim. (0.18): 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# The time of execution of preprocess: 113.3683340549469 s

# %%
n_generated_data = 3054
generated_df = model.sample(n_generated_data)

#concat original data and gan data
data_concat = pd.concat([df, generated_df])
# combine data churn and not churn
data=pd.concat([df1, data_concat])

# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Jun  1 17:31:40 2020

@author: manav

Modifed on 23 AUG 2022

by mahayasa adiputra
"""

import numpy as np
import pandas as pd
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
import matplotlib.pyplot as plt
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix , accuracy_score
from sklearn.metrics import roc_curve, roc_auc_score
import sklearn.metrics as mt
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.under_sampling import TomekLinks
from imblearn.under_sampling import NeighbourhoodCleaningRule
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from numpy import mean
from numpy import std
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import make_scorer
from imblearn.metrics import specificity_score
import math

#data=data.dropna()
#data=data.fillna(0)

start1=time.time()



X=data.drop(['churn'],axis=1)
y=data["churn"]

#enn = EditedNearestNeighbours(n_neighbors=3)
#X, y = enn.fit_resample(X, y)
#ncr = NeighbourhoodCleaningRule(n_neighbors=5, kind_sel='all')
#X, y = ncr.fit_resample(X, y)
#tomek_links = TomekLinks()
#X, y = tomek_links.fit_resample(X, y)


#kfold cross validation
cv = KFold(n_splits=5, random_state=1, shuffle=True)

end1 = time.time()

print("The time of execution of preprocess:",
      (end1-start1), "s")
# Out:
# The time of execution of preprocess: 0.007957935333251953 s

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# decision tree
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
# define grid
balance1 = [{0:10,1:100},{0:20,1:100},{0:30,1:100},{0:40,1:100},{0:50,1:100},{0:60,1:100},{0:70,1:100},{0:80,1:100},{0:90,1:100},{0:100,1:100}]
balance = [{0:100,1:10},{0:100,1:20},{0:100,1:30},{0:100,1:40},{0:100,1:50},{0:100,1:60},{0:100,1:70},{0:100,1:80},{0:100,1:90},{0:100,1:100}]
param_grid = dict(class_weight=balance1)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Create a DataFrame with the results
results_df = pd.DataFrame(grid_result.cv_results_)
# Save the DataFrame to an Excel file
results_df.to_excel('ctgan-telco2-dt-cs-auc.xlsx', index=False)


# Define the source file path (in Colab)
source_file = '/content/ctgan-telco2-dt-cs-auc.xlsx'

# Define the destination folder path in Google Drive
destination_folder = "/content/drive/MyDrive/experiment/telco2"

# Copy the file to the destination
# !cp $source_file $destination_folder
# Out:
# Best: 0.923240 using {'class_weight': {0: 90, 1: 100}}
# 0.903662 (0.006404) with: {'class_weight': {0: 10, 1: 100}}
# 0.913795 (0.008046) with: {'class_weight': {0: 20, 1: 100}}
# 0.915892 (0.009242) with: {'class_weight': {0: 30, 1: 100}}
# 0.922144 (0.008878) with: {'class_weight': {0: 40, 1: 100}}
# 0.919498 (0.005032) with: {'class_weight': {0: 50, 1: 100}}
# 0.917992 (0.004041) with: {'class_weight': {0: 60, 1: 100}}
# 0.920683 (0.004803) with: {'class_weight': {0: 70, 1: 100}}
# 0.921598 (0.009179) with: {'class_weight': {0: 80, 1: 100}}
# 0.923240 (0.005236) with: {'class_weight': {0: 90, 1: 100}}
# 0.921597 (0.006824) with: {'class_weight': {0: 100, 1: 100}}

# %%
from sklearn.metrics import f1_score, make_scorer
f1 = make_scorer(f1_score , average='macro')
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=f1)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Create a DataFrame with the results
results_df = pd.DataFrame(grid_result.cv_results_)
# Save the DataFrame to an Excel file
results_df.to_excel('ctgan-telco2-dt-cs-f1.xlsx', index=False)

# Define the source file path (in Colab)
source_file = '/content/ctgan-telco2-dt-cs-f1.xlsx'

# Define the destination folder path in Google Drive
destination_folder = "/content/drive/MyDrive/experiment/telco2"

# Copy the file to the destination
# !cp $source_file $destination_folder
# Out:
# Best: 0.925561 using {'class_weight': {0: 90, 1: 100}}
# 0.903139 (0.005682) with: {'class_weight': {0: 10, 1: 100}}
# 0.913831 (0.007884) with: {'class_weight': {0: 20, 1: 100}}
# 0.916796 (0.010271) with: {'class_weight': {0: 30, 1: 100}}
# 0.920219 (0.007792) with: {'class_weight': {0: 40, 1: 100}}
# 0.919584 (0.006250) with: {'class_weight': {0: 50, 1: 100}}
# 0.918534 (0.004105) with: {'class_weight': {0: 60, 1: 100}}
# 0.919993 (0.005573) with: {'class_weight': {0: 70, 1: 100}}
# 0.921726 (0.007766) with: {'class_weight': {0: 80, 1: 100}}
# 0.925561 (0.007144) with: {'class_weight': {0: 90, 1: 100}}
# 0.922687 (0.008425) with: {'class_weight': {0: 100, 1: 100}}

# %%
from imblearn.metrics import geometric_mean_score
gm_scorer = make_scorer(geometric_mean_score, greater_is_better=True, average='binary')

grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=gm_scorer)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Create a DataFrame with the results
results_df = pd.DataFrame(grid_result.cv_results_)
# Save the DataFrame to an Excel file
results_df.to_excel('ctgan-telco2-dt-cs-gmean.xlsx', index=False)

# Define the source file path (in Colab)
source_file = '/content/ctgan-telco2-dt-cs-gmean.xlsx'

# Define the destination folder path in Google Drive
destination_folder = "/content/drive/MyDrive/experiment/telco2"

# Copy the file to the destination
# !cp $source_file $destination_folder
# Out:
# Best: 0.924082 using {'class_weight': {0: 100, 1: 100}}
# 0.904003 (0.005663) with: {'class_weight': {0: 10, 1: 100}}
# 0.915587 (0.008174) with: {'class_weight': {0: 20, 1: 100}}
# 0.916597 (0.007674) with: {'class_weight': {0: 30, 1: 100}}
# 0.919769 (0.006834) with: {'class_weight': {0: 40, 1: 100}}
# 0.918995 (0.005944) with: {'class_weight': {0: 50, 1: 100}}
# 0.919477 (0.004427) with: {'class_weight': {0: 60, 1: 100}}
# 0.919178 (0.005068) with: {'class_weight': {0: 70, 1: 100}}
# 0.922829 (0.007744) with: {'class_weight': {0: 80, 1: 100}}
# 0.923534 (0.006164) with: {'class_weight': {0: 90, 1: 100}}
# 0.924082 (0.005589) with: {'class_weight': {0: 100, 1: 100}}

# %%
# LR
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
# define grid
balance1 = [{0:10,1:100},{0:20,1:100},{0:30,1:100},{0:40,1:100},{0:50,1:100},{0:60,1:100},{0:70,1:100},{0:80,1:100},{0:90,1:100},{0:100,1:100}]
balance = [{0:100,1:10},{0:100,1:20},{0:100,1:30},{0:100,1:40},{0:100,1:50},{0:100,1:60},{0:100,1:70},{0:100,1:80},{0:100,1:90},{0:100,1:100}]
param_grid = dict(class_weight=balance1)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Create a DataFrame with the results
results_df = pd.DataFrame(grid_result.cv_results_)
# Save the DataFrame to an Excel file
results_df.to_excel('ctgan-telco2-lr-cs-auc.xlsx', index=False)

# Define the source file path (in Colab)
source_file = '/content/ctgan-telco2-lr-cs-auc.xlsx'

# Define the destination folder path in Google Drive
destination_folder = "/content/drive/MyDrive/experiment/telco2"

# Copy the file to the destination
# !cp $source_file $destination_folder
# Out:
# Best: 0.904134 using {'class_weight': {0: 10, 1: 100}}
# 0.904134 (0.007599) with: {'class_weight': {0: 10, 1: 100}}
# 0.897876 (0.007843) with: {'class_weight': {0: 20, 1: 100}}
# 0.894272 (0.008905) with: {'class_weight': {0: 30, 1: 100}}
# 0.895848 (0.009041) with: {'class_weight': {0: 40, 1: 100}}
# 0.889033 (0.008802) with: {'class_weight': {0: 50, 1: 100}}
# 0.885135 (0.008255) with: {'class_weight': {0: 60, 1: 100}}
# 0.894623 (0.007853) with: {'class_weight': {0: 70, 1: 100}}
# 0.886475 (0.010191) with: {'class_weight': {0: 80, 1: 100}}
# 0.891848 (0.011915) with: {'class_weight': {0: 90, 1: 100}}
# 0.887043 (0.009362) with: {'class_weight': {0: 100, 1: 100}}
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import f1_score, make_scorer
f1 = make_scorer(f1_score , average='macro')
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=f1)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Create a DataFrame with the results
results_df = pd.DataFrame(grid_result.cv_results_)
# Save the DataFrame to an Excel file
results_df.to_excel('ctgan-telco2-lr-cs-f1.xlsx', index=False)


# Define the source file path (in Colab)
source_file = '/content/ctgan-telco2-lr-cs-f1.xlsx'

# Define the destination folder path in Google Drive
destination_folder = "/content/drive/MyDrive/experiment/telco2"

# Copy the file to the destination
# !cp $source_file $destination_folder
# Out:
# Best: 0.828487 using {'class_weight': {0: 100, 1: 100}}
# 0.453163 (0.020817) with: {'class_weight': {0: 10, 1: 100}}
# 0.589295 (0.023007) with: {'class_weight': {0: 20, 1: 100}}
# 0.682661 (0.018864) with: {'class_weight': {0: 30, 1: 100}}
# 0.739412 (0.015548) with: {'class_weight': {0: 40, 1: 100}}
# 0.764442 (0.010867) with: {'class_weight': {0: 50, 1: 100}}
# 0.784363 (0.009837) with: {'class_weight': {0: 60, 1: 100}}
# 0.814302 (0.007710) with: {'class_weight': {0: 70, 1: 100}}
# 0.814852 (0.007958) with: {'class_weight': {0: 80, 1: 100}}
# 0.828033 (0.008691) with: {'class_weight': {0: 90, 1: 100}}
# 0.828487 (0.008739) with: {'class_weight': {0: 100, 1: 100}}
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from imblearn.metrics import geometric_mean_score
gm_scorer = make_scorer(geometric_mean_score, greater_is_better=True, average='binary')
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=gm_scorer)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Create a DataFrame with the results
results_df = pd.DataFrame(grid_result.cv_results_)
# Save the DataFrame to an Excel file
results_df.to_excel('ctgan-telco2-lr-cs-gmean.xlsx', index=False)


# Define the source file path (in Colab)
source_file = '/content/ctgan-telco2-lr-cs-gmean.xlsx'

# Define the destination folder path in Google Drive
destination_folder = "/content/drive/MyDrive/experiment/telco2"

# Copy the file to the destination
# !cp $source_file $destination_folder
# Out:
# Best: 0.827562 using {'class_weight': {0: 90, 1: 100}}
# 0.348592 (0.033133) with: {'class_weight': {0: 10, 1: 100}}
# 0.542749 (0.030201) with: {'class_weight': {0: 20, 1: 100}}
# 0.661256 (0.022047) with: {'class_weight': {0: 30, 1: 100}}
# 0.730011 (0.017313) with: {'class_weight': {0: 40, 1: 100}}
# 0.759912 (0.012168) with: {'class_weight': {0: 50, 1: 100}}
# 0.782688 (0.010390) with: {'class_weight': {0: 60, 1: 100}}
# 0.814098 (0.007854) with: {'class_weight': {0: 70, 1: 100}}
# 0.814652 (0.008092) with: {'class_weight': {0: 80, 1: 100}}
# 0.827562 (0.008795) with: {'class_weight': {0: 90, 1: 100}}
# 0.827440 (0.008911) with: {'class_weight': {0: 100, 1: 100}}
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#SVM
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.svm import SVC
model = SVC()
# define grid
balance1 = [{0:10,1:100},{0:20,1:100},{0:30,1:100},{0:40,1:100},{0:50,1:100},{0:60,1:100},{0:70,1:100},{0:80,1:100},{0:90,1:100},{0:100,1:100}]
balance = [{0:100,1:10},{0:100,1:20},{0:100,1:30},{0:100,1:40},{0:100,1:50},{0:100,1:60},{0:100,1:70},{0:100,1:80},{0:100,1:90},{0:100,1:100}]
param_grid = dict(class_weight=balance1)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Create a DataFrame with the results
results_df = pd.DataFrame(grid_result.cv_results_)
# Save the DataFrame to an Excel file
results_df.to_excel('ctgan-telco2-svm-cs-auc.xlsx', index=False)

# Define the source file path (in Colab)
source_file = '/content/ctgan-telco2-svm-cs-auc.xlsx'

# Define the destination folder path in Google Drive
destination_folder = "/content/drive/MyDrive/experiment/telco2"

# Copy the file to the destination
# !cp $source_file $destination_folder
# Out:
# Best: 0.964894 using {'class_weight': {0: 100, 1: 100}}
# 0.953376 (0.003529) with: {'class_weight': {0: 10, 1: 100}}
# 0.959119 (0.003560) with: {'class_weight': {0: 20, 1: 100}}
# 0.960560 (0.003621) with: {'class_weight': {0: 30, 1: 100}}
# 0.961491 (0.003477) with: {'class_weight': {0: 40, 1: 100}}
# 0.962188 (0.003609) with: {'class_weight': {0: 50, 1: 100}}
# 0.963113 (0.003627) with: {'class_weight': {0: 60, 1: 100}}
# 0.963762 (0.003639) with: {'class_weight': {0: 70, 1: 100}}
# 0.964295 (0.003672) with: {'class_weight': {0: 80, 1: 100}}
# 0.964627 (0.003745) with: {'class_weight': {0: 90, 1: 100}}
# 0.964894 (0.003692) with: {'class_weight': {0: 100, 1: 100}}

# %%
from sklearn.metrics import f1_score, make_scorer
f1 = make_scorer(f1_score , average='macro')
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=f1)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Create a DataFrame with the results
results_df = pd.DataFrame(grid_result.cv_results_)
# Save the DataFrame to an Excel file
results_df.to_excel('ctgan-telco2-svm-cs-f1.xlsx', index=False)

# Define the source file path (in Colab)
source_file = '/content/ctgan-telco2-svm-cs-f1.xlsx'

# Define the destination folder path in Google Drive
destination_folder = "/content/drive/MyDrive/experiment/telco2"

# Copy the file to the destination
# !cp $source_file $destination_folder
# Out:
# Best: 0.918790 using {'class_weight': {0: 70, 1: 100}}
# 0.629238 (0.021074) with: {'class_weight': {0: 10, 1: 100}}
# 0.871715 (0.009105) with: {'class_weight': {0: 20, 1: 100}}
# 0.901868 (0.006946) with: {'class_weight': {0: 30, 1: 100}}
# 0.912715 (0.008499) with: {'class_weight': {0: 40, 1: 100}}
# 0.916999 (0.007212) with: {'class_weight': {0: 50, 1: 100}}
# 0.918553 (0.006674) with: {'class_weight': {0: 60, 1: 100}}
# 0.918790 (0.005770) with: {'class_weight': {0: 70, 1: 100}}
# 0.918523 (0.005777) with: {'class_weight': {0: 80, 1: 100}}
# 0.918438 (0.005675) with: {'class_weight': {0: 90, 1: 100}}
# 0.918126 (0.005883) with: {'class_weight': {0: 100, 1: 100}}

# %%
from imblearn.metrics import geometric_mean_score
gm_scorer = make_scorer(geometric_mean_score, greater_is_better=True, average='binary')
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring=gm_scorer)
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Create a DataFrame with the results
results_df = pd.DataFrame(grid_result.cv_results_)
# Save the DataFrame to an Excel file
results_df.to_excel('ctgan-telco2-svm-cs-gmean.xlsx', index=False)


# Define the source file path (in Colab)
source_file = '/content/ctgan-telco2-svm-cs-gmean.xlsx'

# Define the destination folder path in Google Drive
destination_folder = "/content/drive/MyDrive/experiment/telco2"

# Copy the file to the destination
# !cp $source_file $destination_folder
# Out:
# Best: 0.917887 using {'class_weight': {0: 70, 1: 100}}
# 0.586374 (0.026274) with: {'class_weight': {0: 10, 1: 100}}
# 0.870022 (0.009664) with: {'class_weight': {0: 20, 1: 100}}
# 0.901816 (0.006974) with: {'class_weight': {0: 30, 1: 100}}
# 0.912570 (0.008458) with: {'class_weight': {0: 40, 1: 100}}
# 0.916560 (0.007172) with: {'class_weight': {0: 50, 1: 100}}
# 0.917861 (0.006669) with: {'class_weight': {0: 60, 1: 100}}
# 0.917887 (0.005849) with: {'class_weight': {0: 70, 1: 100}}
# 0.917415 (0.006011) with: {'class_weight': {0: 80, 1: 100}}
# 0.917117 (0.005997) with: {'class_weight': {0: 90, 1: 100}}
# 0.916594 (0.006205) with: {'class_weight': {0: 100, 1: 100}}
